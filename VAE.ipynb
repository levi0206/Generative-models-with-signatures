# %% [markdown]
# # Part II: Variational Autoencoder

# %% [markdown]
# ### Reparameterization Trick

# %% [markdown]
# ![reparameterization trick.png](data:image/png;base64,...)

# %% [markdown]
# ![VAE.png](data:image/png;base64,...)
